# %% [markdown]
# # Example showing how to get time-series data from a sql station

# %%
from soda.dataio.netcdfio import load_sql_ncstation

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
load_sql_ncstation?

# %%
dbfile = '/home/suntans/Share/database/UWAOceanDynamics.sqlite'

qstr = 'height_start < 30.'

varname = 'waterlevel'
station = 'KIM200'

# %%
data = load_sql_ncstation(dbfile, station, varname, otherquery = qstr)
data
# Out:
# LOWER(Variable_Name) LIKE LOWER("waterlevel") and StationName LIKE "%KIM200%" and height_start < 30.
# Querying database...
# LOWER(Variable_Name) LIKE LOWER("waterlevel") and StationName LIKE "%KIM200%" and height_start < 30.
# /home/suntans/Share/ARCHub/DATA/FIELD/IMOS/IMOS_moorings_PILKIM.nc KIM200-1208_SEABIRD_SBE37SM_+_P_267
# /home/suntans/Share/ARCHub/DATA/FIELD/IMOS/IMOS_moorings_PILKIM.nc KIM200-1202_SEABIRD_SBE37SM_+_P_272
# [<xarray.DataArray 'waterlevel' (TIME: 249355)>
#  [249355 values with dtype=float32]
#  Coordinates:
#    * TIME           (TIME) datetime64[ns] 2012-08-10T22:00:00.979200 ...
#      LATITUDE       float64 ...
#      LONGITUDE      float64 ...
#      NOMINAL_DEPTH  float32 ...
#  Attributes:
#      standard_name:        depth
#      long_name:            actual depth
#      units:                m
#      reference_datum:      sea surface
#      positive:             down
#      valid_min:            -5.0
#      valid_max:            12000.0
# ...

# %%
# plot the first station
plt.figure()
data[0].plot()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
data[1].plot(color='r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
